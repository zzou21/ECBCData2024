# %% [markdown]
# TF-IDF practice. Method 1: relying mostly on TfidfVectorizer without pandas
#
# Author: Jerry Zou
#
# Helpful tutorial: https://www.youtube.com/watch?v=i74DVqMsRWY
#
# Helpful note: "the function get_feature_namest() for the vectorizer is now deprecated; when version 1.2 of sklearn is released the function will be completely removed (thus breaking the code in this video). The new standard function to use is to change the line to: vectorizer.get_feature_names_out()."

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from nltk.corpus import stopwords
import string, json, glob, re, os

# %%
# Put the folder pathname here:
folderPath = "/Users/Jerry/Desktop/1622-1626_texts_no_stop"

# The following dictionary stores the content of all files. The document is in this format - key: (type: string. file name without ".txt") | value: (type: string. the text of the document combined into one paragraph):

titleContentDictionary = {}

# The loadFolder function below reads the "folderPath" variable and loads content into the dictionary above.
def loadFolder(folder):
    for filename in os.listdir(folder):
        if filename.endswith(".txt"):
            filePath = os.path.join(folder, filename)
            with open(filePath, "r") as fileToOpen:
                content = fileToOpen.read()
                content = content.replace("\n", "")
                content = " ".join(content.split())
                titleContentDictionary[filename[:-4]] = content
loadFolder(folderPath)

#FOR DEBUG: print(titleContentDictionary["A00002"])

# USE THIS CODE IF YOU WISH TO STORE THE CONTENT OF FILES IN A JSON:
# with open("file.json", "w", encoding="utf-8") as jsonDestination:
#     json.dump(titleContentDictionary, jsonDestination, indent=4)

# %%
# Fucntion to clean stopwords and punctuation marks. Call this function if needed
def cleanStopwordsPunctuation(content):
    splittedContent = content.split()
    withStopwordsRemovedList = []
    for word in splittedContent:
        if word not in stopwords.words("english"):
            withStopwordsRemovedList.append(word)
    withStopwordsRemovedString = " ".join(withStopwordsRemovedList)
    punctuationRemoved = withStopwordsRemovedString.translate(str.maketrans("", "", string.punctuation))

    return(punctuationRemoved)

# %%
# Define TF-IDF vectorizer
vectorizer = TfidfVectorizer(
    lowercase=True,
    max_features = 10, # an integer. This decides how many output terms from most frequent to least frequent you wish the program to provide. For example, max_features = 100 means you wish to see the 100 most frequent terms (ngrams) in the corpus.
    max_df = 0.8, # a float. Words appearing in over 80% of documents will be ignored.
    min_df = 20, # an integer. Words appearing in less than 5 documents will be ignored.
    ngram_range = (1,3), # looking at single word, double-word-group (bigram), and triple-word-group (trigram). From 1 to 3-term pairs. Could change the number to customize the size of the terms you wish to see. E.g.: (2, 3) would mean only searching for bigrams and trigrams.
    stop_words = "english"
)

# %%
# This variable grabs only the values (or the file content) from the "titleContentDictionary" dictionary, since vectorizer only takes in content and not file name. 
contentAsDictValues = titleContentDictionary.values() # Type: <class "dict_values"> . This is NOT a list and should not be passed into "vectorizer.fit_transform" in the next cell!

# This variable stores the content of the files and should be passed into "vectorizer.fit_transform" in the next file.
contentAsList = []

# This "for" loop is to turn the <class "dict_values"> variable "contentAsDictValues" into the <class "list> variable "contentAsList"
for chapter in titleContentDictionary.values():
    contentAsList.append(chapter)
#FOR DEBUG: print(type(contentAsList))

# %%
# THESE VARIABLES ARE FOR DEBUG PURPOSES
# test1 = "Los Angeles is a city of quartz, reflecting the lights from a sun that no longer melts even the snowflakes falling during an afternoon in June of 2026."
# test2 = "San Francisco is a city of quartz, reflecting the lights from a sun that no longer melts even the snowflakes falling during an afternoon in June of 2026."
# test3 = "Detroit is a city of diamonts, reflecting the lights from a moon that no longer melts ice in June of 2025."
# test4 = "Detroit is a city of diamonts, reflecting the lights from a moon that no longer melts ice in June of 2025."

# USE THIS CODE IF YOU ARE STORING YOUR CONTENT IN A JSON RATHER THAN A DICTIONARY
# jsonAsList = []

# with open("/Users/Jerry/Desktop/Submission Diary entries", "r") as file:
#     stories = json.load(file)
#     for story in stories.values():
#         jsonAsList.append(story)

vectors = vectorizer.fit_transform(contentAsList)
featuresNames = vectorizer.get_feature_names_out() #no parameters passed in.
dense = vectors.todense()
denseList = dense.tolist()

#this list will be a list of lists --- i.e.: [[content, content], [content, content], [content, content]] that stores the words deemed as significant by the TF-IDF calculation.
allKeywords = []
# to interpret the "allKeywords" list of lists: the index number of one list is the same as the index number of the file content in the "contentAsList" list. For example, allKeywords[0] calls the first list in the "allKeywords" list of lists. The words in allKeywords[0] are the significant words from the file content stored in contentAsList[0].

for term in denseList:
    x = 0
    keywords = []
    for word in term:
        if word > 0:
            keywords.append(featuresNames[x])
        x += 1
    allKeywords.append(keywords)

# This "for" loop will print out the signifciant words
for list in allKeywords:
    print(list)

# THIS CODE WILL PRINT OUT ALL UNIQUE WORDS DEEMED AS SGINIFICANT FROM THE ENTIRE FOLDER.

# allKeywordsver2Set = set()
# for list in allKeywords:
#     temporarySet = set()
#     for word in list:
#         temporarySet.add(word)
#     for word in temporarySet:
#         allKeywordsver2Set.add(word)
# print(allKeywordsver2Set)
# Out:
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'holy', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'love']
# ['father', 'life']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart', 'holy', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love', 'world']
# ['father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith']
# ['church', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'life', 'love']
# ['faith', 'father']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'holy', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church', 'life', 'love']
# ['church', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['love', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['father']
# ['church', 'father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart']
# ['church', 'father', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'love', 'sin']
# ['christ', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'holy', 'life']
# ['life']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'heart', 'love']
# ['christ', 'church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'holy', 'life', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['heart', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'holy']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father']
# ['heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['faith', 'heart', 'love', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'heart', 'life', 'love', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'sin', 'world']
# ['christ', 'church', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'holy', 'life', 'sin', 'world']
# ['heart', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# []
# ['father', 'love', 'world']
# ['father', 'heart', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['life']
# ['church', 'heart', 'holy', 'life', 'world']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['heart', 'love']
# ['faith']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'love']
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'life', 'love']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love']
# ['church', 'faith', 'father', 'heart', 'life', 'sin']
# ['heart', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['faith']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['church']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['church', 'faith', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'life', 'love', 'world']
# []
# ['church', 'love']
# ['christ', 'faith', 'heart', 'holy', 'life', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'father', 'holy', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love']
# ['church', 'father']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church', 'father', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'heart', 'life']
# ['church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'life', 'love', 'world']
# ['church', 'holy']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'life', 'love', 'world']
# []
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'life']
# ['father', 'heart', 'life', 'love']
# ['world']
# ['church', 'faith', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart']
# ['christ', 'church', 'faith', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'life', 'love', 'sin', 'world']
# ['life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['church', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['heart', 'life', 'world']
# ['christ', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'heart', 'holy', 'life', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['faith']
# ['christ', 'father', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['heart', 'love']
# ['church', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['father', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['father', 'heart']
# ['father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love', 'world']
# ['heart', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'heart', 'love', 'world']
# ['world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['church']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'heart', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['heart']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'life', 'world']
# ['faith']
# ['holy']
# ['faith', 'father', 'holy', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'heart']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'love']
# ['church', 'father', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# []
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'sin', 'world']
# ['church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church', 'father', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'holy', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church']
# ['church', 'holy', 'life', 'love', 'world']
# ['church', 'faith', 'heart', 'holy', 'life', 'love', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['faith', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'life', 'love', 'world']
# ['church', 'faith', 'holy', 'life']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'sin', 'world']
# ['christ', 'father', 'heart', 'life', 'love', 'world']
# ['faith', 'father', 'heart', 'life', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'world']
# ['heart', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'love']
# ['christ', 'church', 'heart', 'holy', 'life', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church', 'father', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['love']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life']
# ['church', 'love', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'sin', 'world']
# ['church', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'life']
# []
# ['christ', 'church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# []
# ['church', 'father', 'holy', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'holy', 'life']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father']
# ['church', 'father']
# ['world']
# ['faith', 'love']
# ['church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'heart', 'holy', 'love', 'world']
# ['father', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'heart', 'holy', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['heart', 'life']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life']
# ['church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'father', 'heart', 'holy', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'heart', 'life', 'love', 'sin', 'world']
# ['church', 'holy', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'holy', 'life', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love', 'sin', 'world']
# ['faith', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'love']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# []
# ['father', 'life', 'world']
# []
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'holy', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['heart']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love', 'sin']
# ['love']
# []
# ['love']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'holy', 'life', 'love', 'world']
# ['church', 'holy', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart', 'life', 'love', 'world']
# ['church', 'life', 'love', 'world']
# ['love']
# ['church', 'faith', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['church', 'father', 'holy', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church', 'father']
# ['church', 'father', 'heart', 'life', 'love', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'holy', 'life', 'love', 'sin']
# ['church', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'holy', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'heart', 'holy', 'life', 'sin', 'world']
# []
# ['heart']
# ['christ']
# []
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love', 'sin']
# ['church', 'love']
# ['church', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['world']
# ...
# ['faith', 'heart']
# ['father', 'life', 'love']
# ['love']
# ['church', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love']
# ['life', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'heart', 'life', 'love', 'world']
# ['faith', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'heart', 'holy', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'holy', 'world']
# ['heart', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love', 'sin']
# []
# ['church', 'faith', 'father', 'heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'heart', 'holy', 'life', 'love', 'world']
# ['father', 'life']
# ['father', 'life', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'world']
# ['heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'world']
# ['faith', 'heart']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['love']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['faith']
# ['christ', 'faith', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['father', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'holy', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'father', 'holy', 'life', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'holy', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love', 'world']
# ['church', 'life', 'love', 'world']
# []
# ['life', 'love', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'life', 'sin']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['heart', 'life']
# []
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['father', 'holy']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'world']
# ['faith', 'heart', 'holy', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['father', 'world']
# ['love']
# ['heart', 'holy', 'world']
# ['faith', 'father', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# []
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'sin']
# ['love']
# ['love']
# ['faith', 'father', 'heart', 'life', 'love', 'world']
# ['love']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['heart', 'love']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'heart', 'holy', 'life', 'love']
# ['christ', 'church', 'faith', 'holy']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'heart', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'life', 'love']
# ['christ', 'faith', 'father', 'life', 'world']
# ['church', 'life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['holy', 'life', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'life', 'love']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'heart', 'sin']
# ['church', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['holy']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# []
# ['faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart', 'holy', 'life', 'love', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life']
# ['church', 'faith', 'father', 'love']
# ['father', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'heart', 'life', 'love', 'sin', 'world']
# ['father']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# []
# ['church']
# ['father', 'love']
# []
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'love', 'world']
# ['holy', 'life', 'sin']
# ['church', 'holy']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['church', 'faith', 'father', 'heart', 'life', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['life', 'love', 'sin', 'world']
# ['father', 'holy', 'life', 'love', 'sin', 'world']
# ['father', 'heart', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'life', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'father', 'heart', 'life', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'world']
# ['love']
# ['father']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['heart', 'love']
# ['love']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'love', 'world']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'church', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['christ', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']
# ['faith', 'father', 'heart', 'life', 'love', 'world']
# ['life']
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']

# %%
uniqueWords = []

for list in allKeywords:
    for word in list:
        if word not in uniqueWords:
            uniqueWords.append(word)
print(uniqueWords)
# Out:
# ['christ', 'church', 'faith', 'father', 'heart', 'holy', 'life', 'love', 'sin', 'world']

# %%
# Clustering using KMeans. Cluster the keywords selected from TF-IDF, and cluster the original texts, to see if these clusters have overlaps

kClusters = 10 #number of clusters
model = KMeans(n_clusters=kClusters, init="k-means++", max_iter=300, n_init=5)
model.fit(vectors)

order_centroids = model.cluster_centers_.argsort()[:, ::-1]
term = vectorizer.get_feature_names_out()

clusterResultDict = {}

for clusterNumber in range(kClusters):
    clusterWords = []
    for index in order_centroids[clusterNumber, :10]: #make sure to have the comma here
        clusterWords.append(term[index])
        clusterResultDict[int(clusterNumber)] = clusterWords
print(clusterResultDict)

with open("KMeansResults.json", "w", encoding="utf-8") as resultFile:
    json.dump(clusterResultDict, resultFile, indent=4)
# Out:
# {0: ['heart', 'life', 'love', 'father', 'world', 'holy', 'church', 'sin', 'faith', 'christ'], 1: ['father', 'life', 'love', 'world', 'holy', 'church', 'christ', 'faith', 'sin', 'heart'], 2: ['faith', 'heart', 'christ', 'love', 'father', 'sin', 'world', 'life', 'church', 'holy'], 3: ['holy', 'world', 'sin', 'love', 'life', 'heart', 'father', 'faith', 'church', 'christ'], 4: ['church', 'christ', 'holy', 'faith', 'father', 'life', 'world', 'sin', 'heart', 'love'], 5: ['christ', 'sin', 'church', 'holy', 'faith', 'life', 'world', 'heart', 'father', 'love'], 6: ['world', 'life', 'love', 'heart', 'father', 'church', 'holy', 'christ', 'faith', 'sin'], 7: ['love', 'heart', 'life', 'father', 'world', 'sin', 'faith', 'holy', 'church', 'christ'], 8: ['sin', 'heart', 'christ', 'life', 'love', 'holy', 'world', 'father', 'church', 'faith'], 9: ['life', 'world', 'love', 'heart', 'father', 'sin', 'church', 'holy', 'faith', 'christ']}

# %%
vectorizer = TfidfVectorizer(
    lowercase=True,
    max_features = 10, # an integer. This decides how many output terms from most frequent to least frequent you wish the program to provide. For example, max_features = 100 means you wish to see the 100 most frequent terms (ngrams) in the corpus.
    max_df = 0.8, # a float. Words appearing in over 80% of documents will be ignored.
    min_df = 70, # an integer. Words appearing in less than 5 documents will be ignored.
    ngram_range = (1,3), # looking at single word, double-word-group (bigram), and triple-word-group (trigram). From 1 to 3-term pairs. Could change the number to customize the size of the terms you wish to see. E.g.: (2, 3) would mean only searching for bigrams and trigrams.
    stop_words = "english"
)
contentAsDictValues = titleContentDictionary.values() # Type: <class "dict_values"> . This is NOT a list and should not be passed into "vectorizer.fit_transform" in the next cell!

contentAsList = []

for chapter in titleContentDictionary.values():
    contentAsList.append(chapter)

vectors = vectorizer.fit_transform(contentAsList)
featuresNames = vectorizer.get_feature_names_out() #no parameters passed in.
dense = vectors.todense()
denseList = dense.tolist()

allKeywords = []

for term in denseList:
    x = 0
    keywords = []
    for word in term:
        if word > 0:
            keywords.append(featuresNames[x])
        x += 1
    allKeywords.append(keywords)

for list in allKeywords:
    print(list)
